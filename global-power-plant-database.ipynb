# %% [markdown]
# # Importing DataFrame

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("global-power-plant-database.csv")
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# We have 908 rows and 25 column

# %% [markdown]
# # Calculating Null Value

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# # Types of dataset

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %% [markdown]
# as per obsevation of last two code we saw there is null value types of data set also mix we need correct that

# %% [markdown]
# # Encoder Process

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
df['primary_fuel']=lencode.fit_transform(df['primary_fuel'])
df['other_fuel1']=lencode.fit_transform(df['other_fuel1'])
df['other_fuel2']=lencode.fit_transform(df['other_fuel2'])
df['owner']=lencode.fit_transform(df['owner'])
df['generation_data_source']=lencode.fit_transform(df['generation_data_source'])
df['source']=lencode.fit_transform(df['source'])
df['url']=lencode.fit_transform(df['url'])
df['country']=lencode.fit_transform(df['country'])
df['country_long']=lencode.fit_transform(df['country_long'])
df['name']=lencode.fit_transform(df['name'])
df['gppd_idnr']=lencode.fit_transform(df['gppd_idnr'])
df['geolocation_source']=lencode.fit_transform(df['geolocation_source'])

# %%
df.dtypes
# Out:
# country                       int32
# country_long                  int32
# name                          int32
# gppd_idnr                     int32
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                  int32
# other_fuel1                   int32
# other_fuel2                   int32
# other_fuel3                 float64
# commissioning_year          float64
# owner                         int32
# source                        int32
# url                           int32
# geolocation_source            int32
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_data_source        int32
# estimated_generation_gwh    float64
# dtype: object

# %% [markdown]
# # Null value Removal

# %%
df['latitude']=df['latitude'].fillna(df['latitude'].mean())
df['longitude']=df['longitude'].fillna(df['longitude'].mean())
df['wepp_id']=df['wepp_id'].fillna(0)
df['other_fuel3']=df['other_fuel3'].fillna(0)
df['commissioning_year']=df['commissioning_year'].fillna(df['commissioning_year'].mean())
df['year_of_capacity_data']=df['year_of_capacity_data'].fillna(df['year_of_capacity_data'].mean())
df['generation_gwh_2013']=df['generation_gwh_2013'].fillna(df['generation_gwh_2013'].mean())
df['generation_gwh_2014']=df['generation_gwh_2014'].fillna(df['generation_gwh_2014'].mean())
df['generation_gwh_2015']=df['generation_gwh_2015'].fillna(df['generation_gwh_2015'].mean())
df['generation_gwh_2016']=df['generation_gwh_2016'].fillna(df['generation_gwh_2016'].mean())
df['generation_gwh_2017']=df['generation_gwh_2017'].fillna(df['generation_gwh_2017'].mean())
df['estimated_generation_gwh']=df['estimated_generation_gwh'].fillna(0)

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                    0
# longitude                   0
# primary_fuel                0
# other_fuel1                 0
# other_fuel2                 0
# other_fuel3                 0
# commissioning_year          0
# owner                       0
# source                      0
# url                         0
# geolocation_source          0
# wepp_id                     0
# year_of_capacity_data       0
# generation_gwh_2013         0
# generation_gwh_2014         0
# generation_gwh_2015         0
# generation_gwh_2016         0
# generation_gwh_2017         0
# generation_data_source      0
# estimated_generation_gwh    0
# dtype: int64

# %% [markdown]
# # Eda Processing

# %%
sns.displot(df['estimated_generation_gwh'])

# %%
sns.displot(df["primary_fuel"])

# %%
sns.histplot(df['other_fuel3'],bins=20)
# Out:
# <AxesSubplot:xlabel='other_fuel3', ylabel='Count'>

# %%
sns.histplot(df['year_of_capacity_data'],bins=20)
# Out:
# <AxesSubplot:xlabel='year_of_capacity_data', ylabel='Count'>

# %%
sns.pairplot(df)

# %% [markdown]
# # describtion of data set

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0          0             0     0        658          2.5   28.1839    73.2407
# 1          0             0     1        520         98.0   24.7663    74.6090
# 2          0             0     2        854         39.2   21.9038    69.3732
# 3          0             0     3          0        135.0   23.8712    91.3602
# 4          0             0     4          1       1800.0   21.9603    82.4091
# ..       ...           ...   ...        ...          ...       ...        ...
# 903        0             0   903        494       1600.0   16.2949    77.3568
# 904        0             0   904        823          3.0   12.8932    78.1654
# 905        0             0   905        892         25.5   15.2758    75.5811
# 906        0             0   906        540         80.0   24.3500    73.7477
# 907        0             0   907        877         16.5    9.9344    77.4768
#
# ...

# %% [markdown]
# # Corelation

# %%
df.corr()
# Out:
#                           capacity_mw  latitude  longitude  other_fuel3  \
# capacity_mw                  1.000000  0.050107   0.198377          NaN
# latitude                     0.050107  1.000000   0.031501          NaN
# longitude                    0.198377  0.031501   1.000000          NaN
# other_fuel3                       NaN       NaN        NaN          NaN
# commissioning_year           0.294661  0.120944   0.114167          NaN
# wepp_id                           NaN       NaN        NaN          NaN
# year_of_capacity_data             NaN       NaN        NaN          NaN
# generation_gwh_2013          0.823513  0.050720   0.017461          NaN
# generation_gwh_2014          0.850698  0.059826   0.013678          NaN
# generation_gwh_2015          0.855834  0.048103   0.023087          NaN
# generation_gwh_2016          0.881209  0.040832   0.051128          NaN
# generation_gwh_2017          0.896785  0.039711   0.049320          NaN
# ...

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(df.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# so by seing all the eda we saw there is outlier

# %% [markdown]
# # Outlier Treatment

# %%
df.skew()
# Out:
# country                      0.000000
# country_long                 0.000000
# name                         0.000000
# gppd_idnr                    0.000000
# capacity_mw                  3.193257
# latitude                    -0.147391
# longitude                    1.129836
# primary_fuel                 0.471141
# other_fuel1                 -1.619441
# other_fuel2                -30.133038
# other_fuel3                  0.000000
# commissioning_year          -1.383330
# owner                       -1.375607
# source                       1.829145
# url                          1.512258
# geolocation_source          -1.922080
# wepp_id                      0.000000
# year_of_capacity_data        0.000000
# generation_gwh_2013          5.241491
# generation_gwh_2014          5.041961
# generation_gwh_2015          5.367370
# generation_gwh_2016          5.071758
# generation_gwh_2017          5.111938
# generation_data_source      -0.017651
# estimated_generation_gwh     0.000000
# ...

# %%
df.shape
# Out:
# (908, 25)

# %% [markdown]
# # Features and Targets when Terget is PrimaryFuel

# %%
features=df.drop("primary_fuel",axis=1)
target=df["primary_fuel"]
x=features
y=target

# %% [markdown]
# # Regrassion Technique

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00, -1.73014431e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -1.72632922e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -1.72251413e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  1.72251413e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.72632922e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.73014431e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00]])

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=55)

# %%
lr=LinearRegression()
lr.fit(xtrain,ytrain)
lr.coef_
# Out:
# array([ 0.00000000e+00, -8.88178420e-16, -4.00071052e-01,  1.20703201e+00,
#        -2.25928271e-01,  3.79320042e-02, -6.67151844e-02,  7.29071367e-01,
#         5.24894401e-16, -1.66533454e-16, -3.87445487e-02,  8.29346958e-01,
#        -1.07490290e+00,  7.74809626e-01, -1.14311131e+00, -2.22044605e-16,
#        -4.44089210e-16, -2.91626572e-04, -1.76217826e-02, -1.28034968e-01,
#         3.61573802e-02,  2.35639510e-01, -5.67337806e-02,  0.00000000e+00])

# %%
list(zip(lr.coef_,features))
# Out:
# [(0.0, 'country'),
#  (-8.881784197001252e-16, 'country_long'),
#  (-0.4000710519587678, 'name'),
#  (1.2070320107330748, 'gppd_idnr'),
#  (-0.22592827079637084, 'capacity_mw'),
#  (0.037932004155855015, 'latitude'),
#  (-0.06671518438668106, 'longitude'),
#  (0.7290713671747961, 'other_fuel1'),
#  (5.248944006299221e-16, 'other_fuel2'),
#  (-1.6653345369377348e-16, 'other_fuel3'),
#  (-0.03874454871150518, 'commissioning_year'),
#  (0.8293469581234316, 'owner'),
#  (-1.0749029012139506, 'source'),
#  (0.7748096263445166, 'url'),
#  (-1.1431113056695, 'geolocation_source'),
#  (-2.220446049250313e-16, 'wepp_id'),
#  (-4.440892098500626e-16, 'year_of_capacity_data'),
#  (-0.00029162657190239406, 'generation_gwh_2013'),
#  (-0.01762178259526151, 'generation_gwh_2014'),
#  (-0.12803496838706144, 'generation_gwh_2015'),
#  (0.036157380240485475, 'generation_gwh_2016'),
#  (0.2356395095623624, 'generation_gwh_2017'),
#  (-0.056733780604049405, 'generation_data_source'),
# ...

# %%
lr.intercept_
# Out:
# 3.2095295011002234

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.8102332530605235

# %%
pred=lr.predict(xtest)
pred
# Out:
# array([ 1.90672797,  1.37392733,  2.65399756,  2.79473523,  2.75440233,
#         2.67384681,  2.15269047,  0.87831205,  2.77583241,  1.12841564,
#         5.87488514,  2.48194402,  6.05554391,  6.76059262,  4.41888273,
#         2.65826651,  3.05080011,  2.72999047,  3.07170081,  6.03463553,
#         3.2374451 ,  6.46154655,  6.30011111,  5.93397549,  1.68084419,
#         0.83481201,  0.17941997,  7.40146799,  1.36078515,  0.93174385,
#         3.25702722,  3.09337652,  2.07653591,  5.8534266 ,  6.96345852,
#         1.5365816 ,  2.8718649 ,  2.17597112,  0.96908311,  2.91994244,
#         0.89998638,  2.69394672,  0.21792611,  5.72222354,  4.91048082,
#         1.83558211,  4.819581  ,  5.79682003,  1.97913776,  6.81010625,
#         2.91363846,  5.80362734,  1.30838666,  2.90396768,  6.26812237,
#         1.38417698,  2.73154531,  2.3465102 ,  1.93601737,  5.45219104,
#         1.70315987,  2.48826117,  0.96646196,  6.34174394,  1.15079673,
# ...

# %%
print('Predicted values',pred)
# Out:
# Predicted values [ 1.90672797  1.37392733  2.65399756  2.79473523  2.75440233  2.67384681
#   2.15269047  0.87831205  2.77583241  1.12841564  5.87488514  2.48194402
#   6.05554391  6.76059262  4.41888273  2.65826651  3.05080011  2.72999047
#   3.07170081  6.03463553  3.2374451   6.46154655  6.30011111  5.93397549
#   1.68084419  0.83481201  0.17941997  7.40146799  1.36078515  0.93174385
#   3.25702722  3.09337652  2.07653591  5.8534266   6.96345852  1.5365816
#   2.8718649   2.17597112  0.96908311  2.91994244  0.89998638  2.69394672
#   0.21792611  5.72222354  4.91048082  1.83558211  4.819581    5.79682003
#   1.97913776  6.81010625  2.91363846  5.80362734  1.30838666  2.90396768
#   6.26812237  1.38417698  2.73154531  2.3465102   1.93601737  5.45219104
#   1.70315987  2.48826117  0.96646196  6.34174394  1.15079673  2.4408033
#   2.43153328  3.38220187  2.48387361  1.6840368   2.2480008   0.59105857
#   0.95873335  2.00813493  2.68777432  2.97629674  2.72699576  2.49889648
# ...

# %%
preddf=pd.DataFrame(data=pred)
preddf
# Out:
#             0
# 0    1.906728
# 1    1.373927
# 2    2.653998
# 3    2.794735
# 4    2.754402
# ..        ...
# 268  0.964317
# 269  2.748542
# 270  4.793008
# 271  3.151036
# 272  3.522010
#
# [273 rows x 1 columns]

# %%
lr.score(xtest,ytest)
# Out:
# 0.7170313379213464

# %%
print('R2 score::',r2_score(ytest,pred))
# Out:
# R2 score:: 0.7170313379213464

# %%
lm=LinearRegression()
lm.fit(xtrain,ytrain)
lm.score(xtrain,ytrain)
pred=lm.predict(xtest)
print('Predicted result:',pred)
print('actual',ytest)
# Out:
# Predicted result: [ 1.90672797  1.37392733  2.65399756  2.79473523  2.75440233  2.67384681
#   2.15269047  0.87831205  2.77583241  1.12841564  5.87488514  2.48194402
#   6.05554391  6.76059262  4.41888273  2.65826651  3.05080011  2.72999047
#   3.07170081  6.03463553  3.2374451   6.46154655  6.30011111  5.93397549
#   1.68084419  0.83481201  0.17941997  7.40146799  1.36078515  0.93174385
#   3.25702722  3.09337652  2.07653591  5.8534266   6.96345852  1.5365816
#   2.8718649   2.17597112  0.96908311  2.91994244  0.89998638  2.69394672
#   0.21792611  5.72222354  4.91048082  1.83558211  4.819581    5.79682003
#   1.97913776  6.81010625  2.91363846  5.80362734  1.30838666  2.90396768
#   6.26812237  1.38417698  2.73154531  2.3465102   1.93601737  5.45219104
#   1.70315987  2.48826117  0.96646196  6.34174394  1.15079673  2.4408033
#   2.43153328  3.38220187  2.48387361  1.6840368   2.2480008   0.59105857
#   0.95873335  2.00813493  2.68777432  2.97629674  2.72699576  2.49889648
# ...

# %%
print('actual result:',ytest)
# Out:
# actual result: 416    1
# 734    1
# 84     3
# 315    3
# 307    3
#       ..
# 456    1
# 226    3
# 196    6
# 792    2
# 902    5
# Name: primary_fuel, Length: 273, dtype: int32

# %%
print('error:')
print(mean_squared_error(pred,ytest))
# Out:
# error:
# 1.448342116301303

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(alpha=0.0001)
ls.fit(xtrain,ytrain)
ls.score(xtrain,ytrain)
# Out:
# 0.810233012135637

# %%
ls.coef_
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -3.99637770e-01,  1.20603117e+00,
#        -2.24482458e-01,  3.78133907e-02, -6.65060978e-02,  7.28958620e-01,
#         0.00000000e+00,  0.00000000e+00, -3.86395795e-02,  8.28924534e-01,
#        -1.07468149e+00,  7.74973830e-01, -1.14309674e+00,  0.00000000e+00,
#         0.00000000e+00, -2.35590978e-04, -1.75767022e-02, -1.24888487e-01,
#         3.24548369e-02,  2.34959080e-01, -5.54808751e-02,  0.00000000e+00])

# %%
rd=Ridge(alpha=0.0001)
rd.fit(xtrain,ytrain)
rd.score(xtrain,ytrain)
# Out:
# 0.8102332530604263

# %%
rd.coef_
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -4.00070555e-01,  1.20703091e+00,
#        -2.25927953e-01,  3.79320107e-02, -6.67152546e-02,  7.29071142e-01,
#         2.56721134e-25,  0.00000000e+00, -3.87445534e-02,  8.29346255e-01,
#        -1.07490243e+00,  7.74809840e-01, -1.14311105e+00,  0.00000000e+00,
#         0.00000000e+00, -2.91700978e-04, -1.76218692e-02, -1.28034389e-01,
#         3.61573073e-02,  2.35638832e-01, -5.67333867e-02,  0.00000000e+00])

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(xtrain,ytrain)
enrpred=enr.predict(xtest)
print(enr.score(xtrain,ytrain))
enr.coef_
# Out:
# 0.8102331540249575
# array([ 0.00000000e+00,  0.00000000e+00, -3.99696787e-01,  1.20618184e+00,
#        -2.25105277e-01,  3.78747719e-02, -6.66330272e-02,  7.28943607e-01,
#         0.00000000e+00,  0.00000000e+00, -3.86936017e-02,  8.28912507e-01,
#        -1.07464389e+00,  7.74959254e-01, -1.14302261e+00,  0.00000000e+00,
#         0.00000000e+00, -2.88472080e-04, -1.76233792e-02, -1.26283790e-01,
#         3.42885951e-02,  2.35083153e-01, -5.59829252e-02,  0.00000000e+00])

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel = 'linear')
svr.fit(xtrain,ytrain)
svr.score(xtrain,ytrain)
pred_y=svr.predict(xtest)
svr = SVR(kernel = 'poly')
svr.fit(xtrain,ytrain)
svr.score(xtrain,ytrain)
pred_y=svr.predict(xtest)
svr = SVR(kernel = 'rbf')
svr.fit(xtrain,ytrain)
svr.score(xtrain,ytrain)
pred_y=svr.predict(xtest)
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(xtrain,ytrain)
    print(sv.score(xtrain,ytrain))
# Out:
# 0.794244366891062
# 0.8602201376861034
# 0.9063410259872228

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(xtrain,ytrain)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf=svr
rf.fit(xtrain, ytrain)
rf.score(xtrain, ytrain)
pred_decision = rf.predict(xtest)

rfs = r2_score(ytest,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 86.62434029355532

# %% [markdown]
# # When Target is Capacity_mw

# %%
features2=df.drop("capacity_mw",axis=1)
target2=df["capacity_mw"]
y1=target2
x1=features2

# %% [markdown]
# # Regression Technique

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
scale=StandardScaler()
x1=scale.fit_transform(x1)
x1
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00, -1.73014431e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -1.72632922e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -1.72251413e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        ...,
#        [ 0.00000000e+00,  0.00000000e+00,  1.72251413e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.72632922e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.73014431e+00, ...,
#         -1.55659091e-16,  9.91227901e-01,  0.00000000e+00]])

# %%
x1train,x1test,y1train,y1test=train_test_split(x1,y1,test_size=0.30,random_state=55)

# %%
lr=LinearRegression()
lr.fit(x1train,y1train)
lr.coef_
# Out:
# array([ 0.00000000e+00, -2.84217094e-14,  1.46852188e+00,  2.24137431e+01,
#        -3.21750278e+00, -3.62180813e+01, -4.36497368e+01, -4.46541511e+01,
#        -9.43003837e-14, -5.68434189e-14,  5.02640048e+01,  1.13940164e+01,
#        -2.54814505e+01,  3.15544500e+00, -1.07858826e+01, -5.68434189e-14,
#         2.84217094e-14,  4.24970466e+01,  3.40689274e+00, -8.99315196e+01,
#         1.31347683e+02,  3.29177606e+02, -2.61194076e+02,  0.00000000e+00])

# %%
list(zip(lr.coef_,features2))
# Out:
# [(0.0, 'country'),
#  (-2.842170943040401e-14, 'country_long'),
#  (1.4685218821492203, 'name'),
#  (22.41374306516976, 'gppd_idnr'),
#  (-3.2175027770152838, 'latitude'),
#  (-36.21808127330967, 'longitude'),
#  (-43.64973680314181, 'primary_fuel'),
#  (-44.65415107791399, 'other_fuel1'),
#  (-9.430038367450027e-14, 'other_fuel2'),
#  (-5.684341886080802e-14, 'other_fuel3'),
#  (50.264004804360525, 'commissioning_year'),
#  (11.39401643065598, 'owner'),
#  (-25.481450480147473, 'source'),
#  (3.15544500292064, 'url'),
#  (-10.785882627509682, 'geolocation_source'),
#  (-5.684341886080802e-14, 'wepp_id'),
#  (2.842170943040401e-14, 'year_of_capacity_data'),
#  (42.49704655702134, 'generation_gwh_2013'),
#  (3.4068927428509888, 'generation_gwh_2014'),
#  (-89.93151964854886, 'generation_gwh_2015'),
#  (131.3476827303478, 'generation_gwh_2016'),
#  (329.1776056042534, 'generation_gwh_2017'),
#  (-261.1940756288281, 'generation_data_source'),
#  (0.0, 'estimated_generation_gwh')]

# %%
lr.intercept_
# Out:
# 323.21415780742893

# %%
lr.score(x1train,y1train)
# Out:
# 0.8728877093271417

# %%
pred=lr.predict(x1test)
pred
# Out:
# array([ 8.37478187e+01,  2.97812655e+02,  3.11438944e+01,  2.13238722e+02,
#         2.54740390e+02,  1.97676960e+02,  4.41498499e+01,  6.47843374e+02,
#         3.30738270e+01,  7.94596299e+02,  2.87615694e+01,  2.52681015e+02,
#         8.24373443e+01,  3.12830250e+01, -1.12969186e+02,  3.01018853e+02,
#         5.12963302e+01,  1.41450326e+02,  1.15225099e+02, -1.18085712e+02,
#         2.42028771e+02,  3.68699534e+01,  2.00656641e+01,  2.84105588e+01,
#         7.08641293e+01,  1.51363043e+03, -6.06421893e+00,  6.30146298e+01,
#         4.95457478e+02,  1.23366227e+03, -9.45476062e+01,  1.60455024e+02,
#         5.81155223e+01,  7.77153592e+01,  2.18847335e+01,  1.15332649e+02,
#         2.20890089e+02,  5.68049616e+01,  1.27862373e+03,  4.85936508e+01,
#         4.95873739e+01,  4.92390329e+02,  5.86120764e+02,  7.26852623e+00,
#         8.41147239e+00,  1.41782799e+01,  2.31557362e+01,  1.75495248e+01,
# ...

# %%
print('Predicted values',pred)
# Out:
# Predicted values [ 8.37478187e+01  2.97812655e+02  3.11438944e+01  2.13238722e+02
#   2.54740390e+02  1.97676960e+02  4.41498499e+01  6.47843374e+02
#   3.30738270e+01  7.94596299e+02  2.87615694e+01  2.52681015e+02
#   8.24373443e+01  3.12830250e+01 -1.12969186e+02  3.01018853e+02
#   5.12963302e+01  1.41450326e+02  1.15225099e+02 -1.18085712e+02
#   2.42028771e+02  3.68699534e+01  2.00656641e+01  2.84105588e+01
#   7.08641293e+01  1.51363043e+03 -6.06421893e+00  6.30146298e+01
#   4.95457478e+02  1.23366227e+03 -9.45476062e+01  1.60455024e+02
#   5.81155223e+01  7.77153592e+01  2.18847335e+01  1.15332649e+02
#   2.20890089e+02  5.68049616e+01  1.27862373e+03  4.85936508e+01
#   4.95873739e+01  4.92390329e+02  5.86120764e+02  7.26852623e+00
#   8.41147239e+00  1.41782799e+01  2.31557362e+01  1.75495248e+01
#   5.80611807e+01  3.54082817e+01  1.71834123e+02  3.75820774e+01
#   1.43901634e+03  8.77542166e+01  1.94121654e+01  2.94513155e+02
# ...

# %%
preddf=pd.DataFrame(data=pred)
preddf
# Out:
#                0
# 0      83.747819
# 1     297.812655
# 2      31.143894
# 3     213.238722
# 4     254.740390
# ..           ...
# 268  1327.878215
# 269    33.425538
# 270   -24.799205
# 271   276.492764
# 272   458.899389
#
# [273 rows x 1 columns]

# %%
lr.score(x1test,y1test)
# Out:
# 0.7672938332907413

# %%
print('R2 score::',r2_score(y1test,pred))
# Out:
# R2 score:: 0.7672938332907413

# %%
lm=LinearRegression()
lm.fit(x1train,y1train)
lm.score(x1train,y1train)
pred=lm.predict(x1test)
print('Predicted result:',pred)
print('actual',y1test)
# Out:
# Predicted result: [ 8.37478187e+01  2.97812655e+02  3.11438944e+01  2.13238722e+02
#   2.54740390e+02  1.97676960e+02  4.41498499e+01  6.47843374e+02
#   3.30738270e+01  7.94596299e+02  2.87615694e+01  2.52681015e+02
#   8.24373443e+01  3.12830250e+01 -1.12969186e+02  3.01018853e+02
#   5.12963302e+01  1.41450326e+02  1.15225099e+02 -1.18085712e+02
#   2.42028771e+02  3.68699534e+01  2.00656641e+01  2.84105588e+01
#   7.08641293e+01  1.51363043e+03 -6.06421893e+00  6.30146298e+01
#   4.95457478e+02  1.23366227e+03 -9.45476062e+01  1.60455024e+02
#   5.81155223e+01  7.77153592e+01  2.18847335e+01  1.15332649e+02
#   2.20890089e+02  5.68049616e+01  1.27862373e+03  4.85936508e+01
#   4.95873739e+01  4.92390329e+02  5.86120764e+02  7.26852623e+00
#   8.41147239e+00  1.41782799e+01  2.31557362e+01  1.75495248e+01
#   5.80611807e+01  3.54082817e+01  1.71834123e+02  3.75820774e+01
#   1.43901634e+03  8.77542166e+01  1.94121654e+01  2.94513155e+02
# ...

# %%
print('error:')
print(mean_squared_error(pred,y1test))
# Out:
# error:
# 52161.24350754101

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(alpha=0.0001)
ls.fit(x1train,y1train)
ls.score(x1train,y1train)
# Out:
# 0.872887709323249

# %%
ls.coef_
# Out:
# array([   0.        ,    0.        ,    1.46882751,   22.41258912,
#          -3.21740692,  -36.21788903,  -43.64831941,  -44.65462627,
#           0.        ,    0.        ,   50.2640449 ,   11.39326344,
#         -25.48057231,    3.15491603,  -10.78494501,    0.        ,
#           0.        ,   42.4979916 ,    3.40400512,  -89.92659164,
#         131.34419555,  329.1781078 , -261.19378923,    0.        ])

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x1train,y1train)
rd.score(x1train,y1train)
# Out:
# 0.8728877093270444

# %%
rd.coef_
# Out:
# array([ 0.00000000e+00,  0.00000000e+00,  1.46857593e+00,  2.24136022e+01,
#        -3.21750201e+00, -3.62180579e+01, -4.36496750e+01, -4.46542240e+01,
#         5.70316547e-22,  0.00000000e+00,  5.02640237e+01,  1.13940022e+01,
#        -2.54814398e+01,  3.15542742e+00, -1.07858679e+01,  0.00000000e+00,
#         0.00000000e+00,  4.24969771e+01,  3.40688245e+00, -8.99309799e+01,
#         1.31347552e+02,  3.29177232e+02, -2.61193914e+02,  0.00000000e+00])

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x1train,y1train)
enrpred=enr.predict(x1test)
print(enr.score(x1train,y1train))
enr.coef_
# Out:
# 0.8728876994222806
# array([   0.        ,    0.        ,    1.4858213 ,   22.36847106,
#          -3.21720978,  -36.21055361,  -43.62941409,  -44.67752753,
#           0.        ,    0.        ,   50.27000972,   11.38914289,
#         -25.47761976,    3.14959901,  -10.78074796,    0.        ,
#           0.        ,   42.47542165,    3.40229271,  -89.75790839,
#         131.30441431,  329.05915769, -261.14278725,    0.        ])

# %%
svr = SVR(kernel = 'linear')
svr.fit(x1train,y1train)
svr.score(x1train,y1train)
pred_y=svr.predict(x1test)
svr = SVR(kernel = 'poly')
svr.fit(x1train,y1train)
svr.score(x1train,y1train)
pred_y=svr.predict(xtest)
svr = SVR(kernel = 'rbf')
svr.fit(x1train,y1train)
svr.score(x1train,y1train)
pred_y=svr.predict(x1test)
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x1train,y1train)
    print(sv.score(x1train,y1train))
# Out:
# 0.7953473465498806
# 0.34039602264120483
# -0.13314103604155614

# %%
parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "log2"]}
rf =RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x1train,y1train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x1train, y1train)
rf.score(x1train, y1train)
pred_decision = rf.predict(x1test)

rfs = r2_score(y1test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 79.51782247829354

# %% [markdown]
# # Conclusion

# %% [markdown]
# After observing both target we recived r2 score 86.62 when target value is Primary fuel and 79.51 when target is Capacity_mw
